# %%
from tools import create_prices_dataframe
import pandas as pd
import matplotlib.pyplot as plt

# %%
target_15m_path = "/Users/zhoupeng/Desktop/crypto_database/data/15MINS"
btc_15_path = "/Users/zhoupeng/Desktop/crypto_database/data/15MINS/BTCUSDT_15m.pkl"
btc_1d_path = "/Users/zhoupeng/Desktop/crypto_database/data/daily/BTCUSDT_1d.pkl"

# %% [markdown]
# 读取某一个数据

# %%
data = pd.read_pickle(btc_15_path)
plt.plot(data['Open time'], data['Close'])

# %% [markdown]
# 把某一个Path下所有数据整合成一张大表

# %%
start_date = "2024-01-01"
end_date = "2024-12-17"

prices_df = create_prices_dataframe(target_15m_path, start_date=start_date, end_date=end_date, fields=['Open', 'Close'])
prices_df
# Out:
#                     CETUSUSDT            SUNUSDT           VELODROMEUSDT  \
#                          Open    Close      Open     Close          Open
# trade_date
# 2024-01-01 00:00:00       NaN      NaN       NaN       NaN           NaN
# 2024-01-01 00:15:00       NaN      NaN       NaN       NaN           NaN
# 2024-01-01 00:30:00       NaN      NaN       NaN       NaN           NaN
# 2024-01-01 00:45:00       NaN      NaN       NaN       NaN           NaN
# 2024-01-01 01:00:00       NaN      NaN       NaN       NaN           NaN
# ...                       ...      ...       ...       ...           ...
# 2024-12-16 23:00:00   0.40985  0.41114  0.025367  0.025279       0.21152
# 2024-12-16 23:15:00   0.41110  0.40851  0.025283  0.025156       0.20961
# 2024-12-16 23:30:00   0.40857  0.40782  0.025162  0.025058       0.20867
# 2024-12-16 23:45:00   0.40781  0.40770  0.025055  0.025085       0.20824
# 2024-12-17 00:00:00   0.40760  0.40524  0.025085  0.024915       0.20972
#
# ...

# %% [markdown]
# 把低freq数据转化成高freq数据

# %%
from tools import resample_to_higher_freq

# 转化成高freq数据
btc_15_data = pd.read_pickle(btc_15_path)
btc_agg_data = resample_to_higher_freq(btc_15_data, target_freq='1d')
btc_agg_data[['Open time', 'Open', 'High', 'Low', 'Close', 'Volume', 'Quote asset volume', 'Number of trades', 'Taker buy base asset volume', 'Taker buy quote asset volume']].head()
# Out:
#    Open time     Open     High      Low    Close      Volume  \
# 0 2020-01-01  7189.43  7260.43  7170.15  7197.57   56801.329
# 1 2020-01-02  7197.57  7209.59  6922.00  6962.04  115295.677
# 2 2020-01-03  6962.34  7407.28  6863.44  7341.72  208493.458
# 3 2020-01-04  7341.60  7400.00  7269.21  7350.71   92586.033
# 4 2020-01-05  7350.54  7495.00  7303.00  7354.36  117765.972
#
#    Quote asset volume  Number of trades  Taker buy base asset volume  \
# 0        4.096788e+08            101871                    28834.200
# 1        8.156278e+08            224747                    55404.262
# 2        1.507314e+09            409820                   107485.965
# 3        6.784024e+08            186349                    46139.090
# 4        8.744885e+08            238905                    58447.543
#
#    Taker buy quote asset volume
# 0                  2.080020e+08
# 1                  3.919117e+08
# 2                  7.770568e+08
# 3                  3.381396e+08
# ...

# %%
# 真实的高freq数据
data = pd.read_pickle(btc_1d_path)
data[['Open time', 'Open', 'High', 'Low', 'Close', 'Volume', 'Quote asset volume', 'Number of trades', 'Taker buy base asset volume', 'Taker buy quote asset volume']].head()
# Out:
#    Open time     Open     High      Low    Close      Volume  \
# 0 2020-01-01  7189.43  7260.43  7170.15  7197.57   56801.329
# 1 2020-01-02  7197.57  7209.59  6922.00  6962.04  115295.677
# 2 2020-01-03  6962.34  7407.28  6863.44  7341.72  208493.458
# 3 2020-01-04  7341.60  7400.00  7269.21  7350.71   92586.033
# 4 2020-01-05  7350.54  7495.00  7303.00  7354.36  117765.972
#
#    Quote asset volume  Number of trades  Taker buy base asset volume  \
# 0        4.096788e+08            101871                    28834.200
# 1        8.156278e+08            224747                    55404.262
# 2        1.507314e+09            409820                   107485.965
# 3        6.784024e+08            186349                    46139.090
# 4        8.744885e+08            238905                    58447.543
#
#    Taker buy quote asset volume
# 0                  2.080020e+08
# 1                  3.919117e+08
# 2                  7.770568e+08
# 3                  3.381396e+08
# ...
